# %%
# Importing dependencies
import pandas as pd
import numpy as np

# Loading the driver stats dataset into a DataFrame
data = pd.read_parquet(path="driver_stats/data/driver_stats_with_string.parquet")

# Sorting the rows by event timestamps, from oldest to newest
data = data.sort_values(by="event_timestamp")

# %%
# Getting the oldest and newest event timestamps from the data
print(f"Earliest event timestamp is {data['event_timestamp'].min()}")
print(f"Latest event timestamp is {data['event_timestamp'].max()}")
# Out:
# Earliest event timestamp is 2021-04-12 07:00:00+00:00
# Latest event timestamp is 2021-09-15 17:00:00+00:00

# %%
# Inspecting the first 25 feature rows
data.head(25)
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 1082 2021-04-12 07:00:00+00:00       1003   0.186658  0.245490
# 721  2021-04-12 07:00:00+00:00       1004   0.891017  0.118256
# 1443 2021-04-12 07:00:00+00:00       1002   0.775499  0.947109
# 360  2021-04-12 07:00:00+00:00       1005   0.138263  0.955520
# 1804 2021-04-12 07:00:00+00:00       1001   0.701558  0.195824
# 722  2021-08-31 18:00:00+00:00       1003   0.494782  0.000316
# 1444 2021-08-31 18:00:00+00:00       1001   0.910018  0.580611
# 1083 2021-08-31 18:00:00+00:00       1002   0.381206  0.347303
# 361  2021-08-31 18:00:00+00:00       1004   0.527224  0.893340
# 0    2021-08-31 18:00:00+00:00       1005   0.362754  0.697629
# 1445 2021-08-31 19:00:00+00:00       1001   0.037472  0.447685
# 723  2021-08-31 19:00:00+00:00       1003   0.635551  0.669229
# 1    2021-08-31 19:00:00+00:00       1005   0.790768  0.821253
# 362  2021-08-31 19:00:00+00:00       1004   0.639311  0.828869
# 1084 2021-08-31 19:00:00+00:00       1002   0.082020  0.250333
# 1085 2021-08-31 20:00:00+00:00       1002   0.859787  0.494235
# 724  2021-08-31 20:00:00+00:00       1003   0.935348  0.221686
# 2    2021-08-31 20:00:00+00:00       1005   0.416623  0.939601
# 363  2021-08-31 20:00:00+00:00       1004   0.352107  0.222272
# 1446 2021-08-31 20:00:00+00:00       1001   0.504876  0.696549
# 725  2021-08-31 21:00:00+00:00       1003   0.040856  0.026880
# 3    2021-08-31 21:00:00+00:00       1005   0.108623  0.818718
# 364  2021-08-31 21:00:00+00:00       1004   0.194456  0.675840
# 1086 2021-08-31 21:00:00+00:00       1002   0.689625  0.350684
# 1447 2021-08-31 21:00:00+00:00       1001   0.662374  0.117641
#
#       avg_daily_trips                 created string_feature
# 1082              971 2021-09-15 18:01:55.403           test
# 721               154 2021-09-15 18:01:55.403           test
# 1443              890 2021-09-15 18:01:55.403           test
# 360               553 2021-09-15 18:01:55.403           test
# 1804              566 2021-09-15 18:01:55.403           test
# 722               634 2021-09-15 18:01:55.403           test
# 1444              666 2021-09-15 18:01:55.403           test
# 1083              268 2021-09-15 18:01:55.403           test
# 361               963 2021-09-15 18:01:55.403           test
# 0                  31 2021-09-15 18:01:55.403           test
# 1445              786 2021-09-15 18:01:55.403           test
# 356               354 2021-09-15 18:01:55.403           test
# 1440              737 2021-09-15 18:01:55.403           test
# 1801              716 2021-09-15 18:01:55.403           test
# 357               557 2021-09-15 18:01:55.403           test
# 1079              194 2021-09-15 18:01:55.403           test
# 718               293 2021-09-15 18:01:55.403           test
# 1802              906 2021-09-15 18:01:55.403           test
# 1441              594 2021-09-15 18:01:55.403           test
# 358               154 2021-09-15 18:01:55.403           test
# 1080              435 2021-09-15 18:01:55.403           test
# 719               951 2021-09-15 18:01:55.403           test
# 720               539 2021-09-15 18:01:55.403           test
# 359               189 2021-09-15 18:01:55.403           test
# 1442              315 2021-09-15 18:01:55.403           test
# 1803              714 2021-09-15 18:01:55.403           test
# 1081               41 2021-09-15 18:01:55.403           test

# %%
# Getting the list of unique driver IDs
print(f"Unique driver IDs are {np.array2string(data['driver_id'].unique())}")
# Out:
# Unique driver IDs are [1003 1004 1002 1005 1001]

# %%
df2 = data
df2.sort_values(["driver_id", "event_timestamp"], inplace=True)
df2["diffs"] = df2.groupby(["driver_id"])["event_timestamp"].transform(lambda x: x.diff())

# %%
df2["diffs"].head()
# Out:
# 1804                 NaT
# 1444   141 days 11:00:00
# 1445     0 days 01:00:00
# 1446     0 days 01:00:00
# 1447     0 days 01:00:00
# Name: diffs, dtype: timedelta64[ns]

# %%
# Checking which indices the time difference is different than one hour
for i in range(len(df2["diffs"])):
    if df2.iloc[i]["diffs"] != pd.Timedelta("0 days 01:00:00"):
        print(f"Timedelta is not one hour for index {i} and its previous index")
# Out:
# Timedelta is not one hour for index 0 and its previous index
# Timedelta is not one hour for index 1 and its previous index
# Timedelta is not one hour for index 361 and its previous index
# Timedelta is not one hour for index 362 and its previous index
# Timedelta is not one hour for index 722 and its previous index
# Timedelta is not one hour for index 723 and its previous index
# Timedelta is not one hour for index 904 and its previous index
# Timedelta is not one hour for index 905 and its previous index
# Timedelta is not one hour for index 1085 and its previous index
# Timedelta is not one hour for index 1086 and its previous index
# Timedelta is not one hour for index 1446 and its previous index
# Timedelta is not one hour for index 1447 and its previous index

# %%
# Difference is not one hour at index 0 because there are no indices before 0
# Difference is not one hour at index 1 because timestamps jump from 2021-04-12 to 2021-08-31
df2[:2]
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 1804 2021-04-12 07:00:00+00:00       1001   0.701558  0.195824
# 1444 2021-08-31 18:00:00+00:00       1001   0.910018  0.580611
#
#       avg_daily_trips                 created string_feature             diffs
# 1804              566 2021-09-15 18:01:55.403           test               NaT
# 1444              666 2021-09-15 18:01:55.403           test 141 days 11:00:00

# %%
# Difference is not one hour at index 361 because previous index is for a different ID
# Difference is not one hour at index 362 because timestamps jump from 2021-04-12 to 2021-08-31
df2[360:363]
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 1803 2021-09-15 17:00:00+00:00       1001   0.812357  0.840873
# 1443 2021-04-12 07:00:00+00:00       1002   0.775499  0.947109
# 1083 2021-08-31 18:00:00+00:00       1002   0.381206  0.347303
#
#       avg_daily_trips                 created string_feature             diffs
# 1803              714 2021-09-15 18:01:55.403           test   0 days 01:00:00
# 1443              890 2021-09-15 18:01:55.403           test               NaT
# 1083              268 2021-09-15 18:01:55.403           test 141 days 11:00:00

# %%
# Difference is not one hour at index 722 because previous index is for a different ID
# Difference is not one hour at index 723 because timestamps jump from 2021-04-12 to 2021-08-31
df2[721:724]
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 1442 2021-09-15 17:00:00+00:00       1002   0.379485  0.151377
# 1082 2021-04-12 07:00:00+00:00       1003   0.186658  0.245490
# 722  2021-08-31 18:00:00+00:00       1003   0.494782  0.000316
#
#       avg_daily_trips                 created string_feature             diffs
# 1442              315 2021-09-15 18:01:55.403           test   0 days 01:00:00
# 1082              971 2021-09-15 18:01:55.403           test               NaT
# 722               634 2021-09-15 18:01:55.403           test 141 days 11:00:00

# %%
# Difference is not one hour at index 904 and 905 because they are duplicates of index 903
df2[903:906]
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 1806 2021-09-08 06:00:00+00:00       1003   0.084715  0.615489
# 1805 2021-09-08 06:00:00+00:00       1003   0.084715  0.615489
# 902  2021-09-08 06:00:00+00:00       1003   0.084715  0.615489
#
#       avg_daily_trips                 created string_feature           diffs
# 1806              523 2021-09-15 18:01:55.403           test 0 days 01:00:00
# 1805              523 2021-09-15 18:01:55.403           test 0 days 00:00:00
# 902               523 2021-09-15 18:01:55.403           test 0 days 00:00:00

# %%
# Difference is not one hour at index 1085 because previous index is for a different ID
# Difference is not one hour at index 1086 because timestamps jump from 2021-04-12 to 2021-08-31
df2[1084:1087]
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 1081 2021-09-15 17:00:00+00:00       1003   0.072028  0.032925
# 721  2021-04-12 07:00:00+00:00       1004   0.891017  0.118256
# 361  2021-08-31 18:00:00+00:00       1004   0.527224  0.893340
#
#       avg_daily_trips                 created string_feature             diffs
# 1081               41 2021-09-15 18:01:55.403           test   0 days 01:00:00
# 721               154 2021-09-15 18:01:55.403           test               NaT
# 361               963 2021-09-15 18:01:55.403           test 141 days 11:00:00

# %%
# Difference is not one hour at index 1446 because previous index is for a different ID
# Difference is not one hour at index 1447 because timestamps jump from 2021-04-12 to 2021-08-31
df2.iloc[1445:1448]
# Out:
#               event_timestamp  driver_id  conv_rate  acc_rate  \
# 720 2021-09-15 17:00:00+00:00       1004   0.541801  0.595369
# 360 2021-04-12 07:00:00+00:00       1005   0.138263  0.955520
# 0   2021-08-31 18:00:00+00:00       1005   0.362754  0.697629
#
#      avg_daily_trips                 created string_feature             diffs
# 720              539 2021-09-15 18:01:55.403           test   0 days 01:00:00
# 360              553 2021-09-15 18:01:55.403           test               NaT
# 0                 31 2021-09-15 18:01:55.403           test 141 days 11:00:00
